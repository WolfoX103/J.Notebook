# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Notebook

# %% [markdown]
# ## Introduction
# This notebook introduces data science concepts, languages, libraries, and tools. It also provides examples of arithmetic expressions using Python.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - Julia

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-Learn

# %% [markdown]
# ## Data Science Tools Table
#
# | Tool            | Description                    |
# |-----------------|--------------------------------|
# | Jupyter Notebook| Interactive data analysis      |
# | Git             | Version control                |
# | TensorFlow      | Machine learning framework     |
# | Docker          | Containerization platform      |

# %% [markdown]
# ## Arithmetic Expressions Examples
# In this section, we'll explore some simple arithmetic expressions.

# %%
# Multiply two numbers
result = 4 * 6
print("Multiplication:", result)

# Add two numbers
result = 10 + 7
print("Addition:", result)

# %%
# Convert minutes to hours
minutes = 120
hours = minutes / 60
print("Conversion:", hours, "hours")

# %% [markdown]
# ## Objectives
# - Introduce data science languages, libraries, and tools.
# - Provide examples of arithmetic expressions.

# %% [markdown]
# ## Author
# - F.M. SADMAN AHMED
